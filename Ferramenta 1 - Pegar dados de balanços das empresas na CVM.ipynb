# %%
import pandas as pd
import requests
import os
import zipfile

# %% [markdown]
# link do site: https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/

# %%
os.chdir(r'C:\Dev\Github\dados_cvm')

# %%
url_base = f'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/'

anos = range(2010, 2024)

for ano in anos:
    
    download = requests.get(url_base + f'dfp_cia_aberta_{ano}.zip')
    
    open(f'dfp_cia_aberta_{ano}.zip', 'wb').write(download.content)

# %%
lista_demonstracoes_2010_2023 = []

# %%
diretorio_atual = os.getcwd()

for arquivo in os.listdir(diretorio_atual):
    arquivo_zip = zipfile.ZipFile(arquivo)
    tipo = 'dfp'
    ano = arquivo[-8:-4]
    
    for planilha in arquivo_zip.namelist():
        if planilha != f'{tipo}_cia_aberta_{ano}.csv':
                        
            demonstracao = pd.read_csv(arquivo_zip.open(planilha), sep = ';', 
                                       decimal = ',', encoding = 'ISO-8859-1', chunksize = 1000)
            
            demonstracao = pd.concat(demonstracao, ignore_index = True)
            
            demonstracao['tipo_doc'] = len(demonstracao) * [tipo] 
            
            lista_demonstracoes_2010_2023.append(demonstracao)

# %%
base_dados = pd.concat(lista_demonstracoes_2010_2023)

# %%
base_dados[['con_ind', 'tipo_dem']] = base_dados['GRUPO_DFP'].str.split('-', expand = True)

base_dados['tipo_dem'] = base_dados['tipo_dem'].str.strip()
base_dados['con_ind'] = base_dados['con_ind'].str.strip()
base_dados['con_ind'] = base_dados['con_ind'].astype(str)

# %%
base_dados = base_dados.loc[:, ~base_dados.columns.isin(['ST_CONTA_FIXA', 'COLUNA_DF', 'GRUPO_DFP'])]

# %%
base_dados = base_dados[base_dados['ORDEM_EXERC'] != 'PENÚLTIMO']

# %%
lista_empresas = base_dados['DENOM_CIA'].unique()
lista_empresas
# Out:
# array(['BCO BRASIL S.A.', 'BRB BCO DE BRASILIA S.A.',
#        'CENTRAIS ELET BRAS S.A. - ELETROBRAS', ...,
#        'VRENTAL LOCAÇÃO DE MÁQUINAS E EQUIPAMENTOS S.A.',
#        'RIO+ SANEAMENTO BL 3 S.A.', 'NOVA SOCIEDADE DE NAVEGAÇÃO S.A.'],
#       dtype=object)

# %%
weg_dre = base_dados[(base_dados['DENOM_CIA'] == 'WEG S.A.') &
                    (base_dados['tipo_dem'] == 'Demonstração do Resultado') &
                    (base_dados['tipo_doc'] == 'dfp') &
                     (base_dados['DS_CONTA'] == 'Receita de Venda de Bens e/ou Serviços') &
                     (base_dados['con_ind'] == 'DF Consolidado')] 

weg_dre
# Out:
#                  CNPJ_CIA    DT_REFER VERSAO DENOM_CIA CD_CVM MOEDA  \
# 22814  84.429.695/0001-11  2010-12-31      1  WEG S.A.   5410  REAL
# 23721  84.429.695/0001-11  2011-12-31      1  WEG S.A.   5410  REAL
# 23379  84.429.695/0001-11  2012-12-31      1  WEG S.A.   5410  REAL
# 22975  84.429.695/0001-11  2013-12-31      1  WEG S.A.   5410  REAL
# 22612  84.429.695/0001-11  2014-12-31      1  WEG S.A.   5410  REAL
# 22410  84.429.695/0001-11  2015-12-31      1  WEG S.A.   5410  REAL
# 22497  84.429.695/0001-11  2016-12-31      1  WEG S.A.   5410  REAL
# 22381  84.429.695/0001-11  2017-12-31      1  WEG S.A.   5410  REAL
# 22209  84.429.695/0001-11  2018-12-31      2  WEG S.A.   5410  REAL
# 24766  84.429.695/0001-11  2019-12-31      1  WEG S.A.   5410  REAL
# 28485  84.429.695/0001-11  2020-12-31      1  WEG S.A.   5410  REAL
# 29847  84.429.695/0001-11  2021-12-31      1  WEG S.A.   5410  REAL
# 30013  84.429.695/0001-11  2022-12-31      1  WEG S.A.   5410  REAL
#
#       ESCALA_MOEDA ORDEM_EXERC DT_FIM_EXERC CD_CONTA  \
# 22814          MIL      ÚLTIMO   2010-12-31     3.01
# 23721          MIL      ÚLTIMO   2011-12-31     3.01
# 23379          MIL      ÚLTIMO   2012-12-31     3.01
# 22975          MIL      ÚLTIMO   2013-12-31     3.01
# 22612          MIL      ÚLTIMO   2014-12-31     3.01
# 22410          MIL      ÚLTIMO   2015-12-31     3.01
# 22497          MIL      ÚLTIMO   2016-12-31     3.01
# 22381          MIL      ÚLTIMO   2017-12-31     3.01
# 22209          MIL      ÚLTIMO   2018-12-31     3.01
# 24766          MIL      ÚLTIMO   2019-12-31     3.01
# 28485          MIL      ÚLTIMO   2020-12-31     3.01
# 29847          MIL      ÚLTIMO   2021-12-31     3.01
# 30013          MIL      ÚLTIMO   2022-12-31     3.01
#
#                                      DS_CONTA             VL_CONTA tipo_doc  \
# 22814  Receita de Venda de Bens e/ou Serviços   4391973.0000000000      dfp
# 23721  Receita de Venda de Bens e/ou Serviços   5189409.0000000000      dfp
# 23379  Receita de Venda de Bens e/ou Serviços   6173878.0000000000      dfp
# 22975  Receita de Venda de Bens e/ou Serviços   6828896.0000000000      dfp
# 22612  Receita de Venda de Bens e/ou Serviços   7840757.0000000000      dfp
# 22410  Receita de Venda de Bens e/ou Serviços   9760323.0000000000      dfp
# 22497  Receita de Venda de Bens e/ou Serviços   9367008.0000000000      dfp
# 22381  Receita de Venda de Bens e/ou Serviços   9523830.0000000000      dfp
# 22209  Receita de Venda de Bens e/ou Serviços  11970090.0000000000      dfp
# 24766  Receita de Venda de Bens e/ou Serviços  13347434.0000000000      dfp
# 28485  Receita de Venda de Bens e/ou Serviços  17469557.0000000000      dfp
# 29847  Receita de Venda de Bens e/ou Serviços  23563338.0000000000      dfp
# 30013  Receita de Venda de Bens e/ou Serviços  29904722.0000000000      dfp
#
#       DT_INI_EXERC         con_ind                   tipo_dem
# 22814   2010-01-01  DF Consolidado  Demonstração do Resultado
# 23721   2011-01-01  DF Consolidado  Demonstração do Resultado
# 23379   2012-01-01  DF Consolidado  Demonstração do Resultado
# 22975   2013-01-01  DF Consolidado  Demonstração do Resultado
# 22612   2014-01-01  DF Consolidado  Demonstração do Resultado
# 22410   2015-01-01  DF Consolidado  Demonstração do Resultado
# 22497   2016-01-01  DF Consolidado  Demonstração do Resultado
# 22381   2017-01-01  DF Consolidado  Demonstração do Resultado
# 22209   2018-01-01  DF Consolidado  Demonstração do Resultado
# 24766   2019-01-01  DF Consolidado  Demonstração do Resultado
# 28485   2020-01-01  DF Consolidado  Demonstração do Resultado
# 29847   2021-01-01  DF Consolidado  Demonstração do Resultado
# 30013   2022-01-01  DF Consolidado  Demonstração do Resultado
