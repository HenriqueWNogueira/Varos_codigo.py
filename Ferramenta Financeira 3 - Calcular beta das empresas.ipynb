# %% [markdown]
# ## Beta de uma ação

# %%
import yfinance as yf
import statsmodels.api as sm
from datetime import timedelta
from datetime import datetime

# %%
ativos = ['WEGE3.SA', '^BVSP']
data = datetime.now()
tres_anos_atras = data - timedelta(days = 1095)

dados_cotacoes = yf.download(ativos, tres_anos_atras, data)['Adj Close']

dados_cotacoes
# Out:
# [*********************100%***********************]  2 of 2 completed
#              WEGE3.SA     ^BVSP
# Date
# 2020-10-05  33.588306   96089.0
# 2020-10-06  34.210495   95615.0
# 2020-10-07  35.019333   95526.0
# 2020-10-08  35.981323   97920.0
# 2020-10-09  36.804516   97483.0
# ...               ...       ...
# 2023-09-27  36.020000  114327.0
# 2023-09-28  36.389999  115731.0
# 2023-09-29  36.270000  116565.0
# 2023-10-02  36.150002  115057.0
# 2023-10-03  35.169998  113419.0
#
# [745 rows x 2 columns]

# %%
retornos_diarios = dados_cotacoes.pct_change().dropna() 

retornos_diarios
# Out:
#             WEGE3.SA     ^BVSP
# Date
# 2020-10-06  0.018524 -0.004933
# 2020-10-07  0.023643 -0.000931
# 2020-10-08  0.027470  0.025061
# 2020-10-09  0.022878 -0.004463
# 2020-10-13  0.029259  0.010463
# ...              ...       ...
# 2023-09-27 -0.001663  0.001173
# 2023-09-28  0.010272  0.012281
# 2023-09-29 -0.003298  0.007206
# 2023-10-02 -0.003308 -0.012937
# 2023-10-03 -0.027109 -0.014236
#
# [744 rows x 2 columns]

# %%
X = retornos_diarios['^BVSP']
Y = retornos_diarios[ativos[0]]

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

# %%
# BETA

print(model.params[1])
print(model.rsquared)
print('----------------------')
print(str(model.summary()))
# Out:
# 0.7746324304760389
# 0.22025244566402502
# ----------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WEGE3.SA   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     209.6
# Date:                Wed, 04 Oct 2023   Prob (F-statistic):           5.11e-42
# Time:                        09:20:49   Log-Likelihood:                 1904.5
# No. Observations:                 744   AIC:                            -3805.
# Df Residuals:                     742   BIC:                            -3796.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.835e-05      0.001      0.070      0.944      -0.001       0.001
# ^BVSP          0.7746      0.054     14.477      0.000       0.670       0.880
# ==============================================================================
# Omnibus:                       71.338   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              161.535
# Skew:                           0.547   Prob(JB):                     8.38e-36
# Kurtosis:                       5.003   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
